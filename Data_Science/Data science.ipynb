# %% [markdown]
# Data Cleaning and Preprocessing

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r'C:\Users\SanthoshKumarE\Desktop\final webapp\Data_Science\combined_report_data.csv')

# Set display options to show all columns
pd.set_option('display.max_columns', None)  # None means no limit on columns
pd.set_option('display.max_rows', None)     # Optional: To see all rows if needed

# Print all column names and their data types
print("Column Names and Data Types:")
print(df.dtypes)

# Drop specified columns
columns_to_drop = [
    'email', 'phone', 'startDate', 'dateOfBirth', 'gender', 
    'address', 'verify', 'additionalAchievements', 'dateAchieved', 
    'organization', 'achievementTitle', 'description', 
    'additionalCertifications', 'dateObtained', 'additionalCourses','category','courseDuration', 'duration'
]
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')  # errors='ignore' avoids errors if columns don't exist

# Fill missing values for categorical columns with mode or 'None'
categorical_columns = [
    'programmingLanguages', 'courseName', 'platform_x', 'specialization_x',
    'courseType', 'completionStatus', 'certificationTitle', 'platform_y',
    'specialization_y',  'favoriteProject',
    'position', 'employmentStatus', 'projectType'
]

for column in categorical_columns:
    # Fill with mode or 'None'
    mode_value = df[column].mode()[0] if not df[column].mode().empty else 'None'
    df[column] = df[column].fillna(mode_value)

# Fill missing values for numerical columns with mean
numerical_columns = [
    'communication', 'problemSolving', 'timeManagement', 
    'softwareEngineerProjects', 'consultantProjects', 'fullStackProjects', 
    'dataAnalystProjects', 'dataEngineerProjects', 'dataScienceProjects', 
    'otherProjects', 'teamwork', 'adaptability', 'criticalThinking', 
    'creativity', 'leadership', 'interpersonalSkills', 'emotionalIntelligence', 
    'programmingLanguages', 'webDevelopment', 'databaseManagement', 
    'cloudComputing', 'versionControl', 'machineLearning', 
    'dataAnalysis', 'cybersecurity', 'totalCoursesCompleted'
    
]

for column in numerical_columns:
    # Fill with mean or median
    mean_value = df[column].mode() if df[column].notnull().any() else 0
    df[column] = df[column].fillna(mean_value)



# Reset index (optional)
df.reset_index(drop=True, inplace=True)

# Display the first few rows to confirm changes
df.head()
# Out:
# Column Names and Data Types:
# firstName                    object
# lastName                     object
# email                        object
# phone                       float64
# position                     object
# employeeid                   object
# startDate                    object
# dateOfBirth                  object
# gender                       object
# address                      object
# employmentStatus             object
# userId                       object
# softwareEngineerProjects      int64
# consultantProjects            int64
# fullStackProjects             int64
# dataAnalystProjects           int64
# dataEngineerProjects          int64
# dataScienceProjects           int64
# otherProjects                 int64
# projectType                  object
# toolsUsed                    object
# favoriteProject              object
# communication                 int64
# teamwork                     object
# problemSolving                int64
# adaptability                 object
# timeManagement                int64
# criticalThinking             object
# creativity                   object
# leadership                   object
# interpersonalSkills          object
# emotionalIntelligence        object
# programmingLanguages          int64
# webDevelopment                int64
# databaseManagement            int64
# cloudComputing               object
# versionControl               object
# machineLearning              object
# dataAnalysis                 object
# cybersecurity                object
# courseName                   object
# platform_x                   object
# specialization_x             object
# totalCoursesCompleted       float64
# courseDuration              float64
# courseType                   object
# completionStatus             object
# additionalCourses            object
# verify                       object
# certificationTitle           object
# platform_y                   object
# specialization_y             object
# dateObtained                 object
# duration                    float64
# additionalCertifications     object
# competencyLevel              object
# achievementTitle             object
# organization                 object
# dateAchieved                 object
# description                  object
# category                     object
# additionalAchievements       object
# dtype: object
#         firstName lastName        position employeeid employmentStatus  \
# 0  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 1  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 2  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 3  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 4  Caitlin Wilson   Nguyen  Data Scientist    JMD2737         contract
#
#                                  userId  softwareEngineerProjects  \
# 0  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 1  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 2  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 3  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 4  0001d2a9-1b26-4bc5-b1de-a55e58696e32                         5
#
#    consultantProjects  fullStackProjects  dataAnalystProjects  \
# 0                   5                  2                    5
# 1                   5                  2                    5
# 2                   5                  2                    5
# 3                   5                  2                    5
# 4                   1                  3                    2
#
#    dataEngineerProjects  dataScienceProjects  otherProjects  \
# 0                     5                    0              3
# 1                     5                    0              3
# 2                     5                    0              3
# 3                     5                    0              3
# 4                     4                    1              0
#
#             projectType toolsUsed     favoriteProject  communication  \
# 0          Data Science   Tableau     Them fact care.              6
# 1          Data Science   Tableau     Them fact care.              6
# 2          Data Science   Tableau     Them fact care.              6
# 3          Data Science   Tableau     Them fact care.              6
# 4  Software Engineering   Node.js  Seem nature story.              9
#
#        teamwork  problemSolving adaptability  timeManagement criticalThinking  \
# 0     Innovator              10    Visionary               4           Leader
# 1     Innovator              10    Visionary               4           Leader
# 2     Innovator              10    Visionary               4           Leader
# 3     Innovator              10    Visionary               4           Leader
# 4  Collaborator              10    Visionary               3       Strategist
#
#    creativity leadership interpersonalSkills emotionalIntelligence  \
# 0  Innovative    Manager            Empathic                Leader
# 1  Innovative    Manager            Empathic                Leader
# 2  Innovative    Manager            Empathic                Leader
# 3  Innovative    Manager            Empathic                Leader
# 4   Visionary  Innovator            Empathic              Empathic
#
#    programmingLanguages  webDevelopment  databaseManagement   cloudComputing  \
# 0                     5               4                   4           Master
# 1                     5               4                   4           Master
# 2                     5               4                   4           Master
# 3                     5               4                   4           Master
# 4                     3               2                   3  Very proficient
#
#           versionControl machineLearning  dataAnalysis          cybersecurity  \
# 0                 Master        Beginner      Beginner                 Master
# 1                 Master        Beginner      Beginner                 Master
# 2                 Master        Beginner      Beginner                 Master
# 3                 Master        Beginner      Beginner                 Master
# 4  Moderately proficient        Beginner  Intermediate  Moderately proficient
#
#          courseName         platform_x      specialization_x  \
# 0   Web Development              Udemy  Software Engineering
# 1            Python                ADF          Data Science
# 2  Machine Learning  LinkedIn Learning          Data Science
# 3  Machine Learning                edX          Data Science
# 4   Web Development  LinkedIn Learning       Web Development
#
#    totalCoursesCompleted        courseType completionStatus  \
# 0                   47.0     Online Course      In Progress
# 1                   52.0  In-Person Course        Completed
# 2                   83.0     Online Course        Completed
# 3                   93.0     Online Course        Completed
# 4                   24.0  In-Person Course      In Progress
#
#   certificationTitle platform_y specialization_y competencyLevel
# 0       Data Science   Coursera  Cloud Computing        Beginner
# 1       Data Science   Coursera  Cloud Computing        Beginner
# 2       Data Science   Coursera  Cloud Computing        Beginner
# 3       Data Science   Coursera  Cloud Computing        Beginner
# 4                AWS        edX  Web Development        Beginner

# %%
# Check for null values in each column
null_counts = df.isnull().sum()
print("\nNull Values Count in Each Column:")
print(null_counts[null_counts > 0])

# Fill missing values for 'competencyLevel' with mode
competency_mode = df['competencyLevel'].mode()[0]
df['competencyLevel'].fillna(competency_mode, inplace=True)

# Fill missing values for 'totalCoursesCompleted' with mean
total_courses_mean = df['totalCoursesCompleted'].mean()
df['totalCoursesCompleted'].fillna(total_courses_mean, inplace=True)

# Check again for null values after filling
print("\nNull Values Count in Each Column After Filling:")
print(df.isnull().sum())

# Display the first few rows to confirm changes
print("\nFirst Few Rows of the Dataset After Filling Missing Values:")
df.head()
# Out:
# Null Values Count in Each Column:
# totalCoursesCompleted    30647
# competencyLevel          30571
# dtype: int64
#
# Null Values Count in Each Column After Filling:
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\1008345284.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['competencyLevel'].fillna(competency_mode, inplace=True)
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\1008345284.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['totalCoursesCompleted'].fillna(total_courses_mean, inplace=True)
# firstName                   0
# lastName                    0
# position                    0
# employeeid                  0
# employmentStatus            0
# userId                      0
# softwareEngineerProjects    0
# consultantProjects          0
# fullStackProjects           0
# dataAnalystProjects         0
# dataEngineerProjects        0
# dataScienceProjects         0
# otherProjects               0
# projectType                 0
# toolsUsed                   0
# favoriteProject             0
# communication               0
# teamwork                    0
# problemSolving              0
# adaptability                0
# timeManagement              0
# criticalThinking            0
# creativity                  0
# leadership                  0
# interpersonalSkills         0
# emotionalIntelligence       0
# programmingLanguages        0
# webDevelopment              0
# databaseManagement          0
# cloudComputing              0
# versionControl              0
# machineLearning             0
# dataAnalysis                0
# cybersecurity               0
# courseName                  0
# platform_x                  0
# specialization_x            0
# totalCoursesCompleted       0
# courseType                  0
# completionStatus            0
# certificationTitle          0
# platform_y                  0
# specialization_y            0
# competencyLevel             0
# dtype: int64
#
# First Few Rows of the Dataset After Filling Missing Values:
#         firstName lastName        position employeeid employmentStatus  \
# 0  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 1  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 2  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 3  Edgar Williams  Hawkins   Data Engineer    JMD9745         contract
# 4  Caitlin Wilson   Nguyen  Data Scientist    JMD2737         contract
#
#                                  userId  softwareEngineerProjects  \
# 0  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 1  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 2  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 3  0000aaaf-2a69-41fb-824b-975974e3a198                         0
# 4  0001d2a9-1b26-4bc5-b1de-a55e58696e32                         5
#
#    consultantProjects  fullStackProjects  dataAnalystProjects  \
# 0                   5                  2                    5
# 1                   5                  2                    5
# 2                   5                  2                    5
# 3                   5                  2                    5
# 4                   1                  3                    2
#
#    dataEngineerProjects  dataScienceProjects  otherProjects  \
# 0                     5                    0              3
# 1                     5                    0              3
# 2                     5                    0              3
# 3                     5                    0              3
# 4                     4                    1              0
#
#             projectType toolsUsed     favoriteProject  communication  \
# 0          Data Science   Tableau     Them fact care.              6
# 1          Data Science   Tableau     Them fact care.              6
# 2          Data Science   Tableau     Them fact care.              6
# 3          Data Science   Tableau     Them fact care.              6
# 4  Software Engineering   Node.js  Seem nature story.              9
#
#        teamwork  problemSolving adaptability  timeManagement criticalThinking  \
# 0     Innovator              10    Visionary               4           Leader
# 1     Innovator              10    Visionary               4           Leader
# 2     Innovator              10    Visionary               4           Leader
# 3     Innovator              10    Visionary               4           Leader
# 4  Collaborator              10    Visionary               3       Strategist
#
#    creativity leadership interpersonalSkills emotionalIntelligence  \
# 0  Innovative    Manager            Empathic                Leader
# 1  Innovative    Manager            Empathic                Leader
# 2  Innovative    Manager            Empathic                Leader
# 3  Innovative    Manager            Empathic                Leader
# 4   Visionary  Innovator            Empathic              Empathic
#
#    programmingLanguages  webDevelopment  databaseManagement   cloudComputing  \
# 0                     5               4                   4           Master
# 1                     5               4                   4           Master
# 2                     5               4                   4           Master
# 3                     5               4                   4           Master
# 4                     3               2                   3  Very proficient
#
#           versionControl machineLearning  dataAnalysis          cybersecurity  \
# 0                 Master        Beginner      Beginner                 Master
# 1                 Master        Beginner      Beginner                 Master
# 2                 Master        Beginner      Beginner                 Master
# 3                 Master        Beginner      Beginner                 Master
# 4  Moderately proficient        Beginner  Intermediate  Moderately proficient
#
#          courseName         platform_x      specialization_x  \
# 0   Web Development              Udemy  Software Engineering
# 1            Python                ADF          Data Science
# 2  Machine Learning  LinkedIn Learning          Data Science
# 3  Machine Learning                edX          Data Science
# 4   Web Development  LinkedIn Learning       Web Development
#
#    totalCoursesCompleted        courseType completionStatus  \
# 0                   47.0     Online Course      In Progress
# 1                   52.0  In-Person Course        Completed
# 2                   83.0     Online Course        Completed
# 3                   93.0     Online Course        Completed
# 4                   24.0  In-Person Course      In Progress
#
#   certificationTitle platform_y specialization_y competencyLevel
# 0       Data Science   Coursera  Cloud Computing        Beginner
# 1       Data Science   Coursera  Cloud Computing        Beginner
# 2       Data Science   Coursera  Cloud Computing        Beginner
# 3       Data Science   Coursera  Cloud Computing        Beginner
# 4                AWS        edX  Web Development        Beginner

# %% [markdown]
# Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(8, 4))

# Create the count plot
bar_plot = sns.countplot(data=df, x='position', palette='Set2')

# Set the title and labels
plt.title('Distribution of Employee Positions')
plt.xlabel('Position')
plt.ylabel('Count')



# Add count on top of each bar, horizontally
for p in bar_plot.patches:
    bar_plot.annotate(f'{int(p.get_height())}', 
                      (p.get_x() + p.get_width() / 2., p.get_height()), 
                      ha='center', va='bottom', 
                      fontsize=10, color='black', 
                      rotation=0,  # Set rotation to 0 for horizontal text
                      xytext=(0, 5),  # Offset the text a bit above the bar
                      textcoords='offset points')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\2556048798.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.countplot(data=df, x='position', palette='Set2')

# %%
descriptive_stats = df.describe()
descriptive_stats
# Out:
#        softwareEngineerProjects  consultantProjects  fullStackProjects  \
# count             487230.000000       487230.000000      487230.000000
# mean                   5.025608            2.499154           2.496995
# std                    3.163968            1.709148           1.707595
# min                    0.000000            0.000000           0.000000
# 25%                    2.000000            1.000000           1.000000
# 50%                    5.000000            3.000000           2.000000
# 75%                    8.000000            4.000000           4.000000
# max                   10.000000            5.000000           5.000000
#
#        dataAnalystProjects  dataEngineerProjects  dataScienceProjects  \
# count        487230.000000         487230.000000        487230.000000
# mean              2.507280              4.987858             5.000205
# std               1.713713              3.171699             3.172238
# min               0.000000              0.000000             0.000000
# 25%               1.000000              2.000000             2.000000
# 50%               3.000000              5.000000             5.000000
# 75%               4.000000              8.000000             8.000000
# max               5.000000             10.000000            10.000000
#
#        otherProjects  communication  problemSolving  timeManagement  \
# count  487230.000000  487230.000000   487230.000000   487230.000000
# mean        1.496107       5.492219        5.512308        5.546071
# std         1.117439       2.875841        2.882607        2.871743
# min         0.000000       1.000000        1.000000        1.000000
# 25%         0.000000       3.000000        3.000000        3.000000
# 50%         2.000000       5.000000        6.000000        6.000000
# 75%         2.000000       8.000000        8.000000        8.000000
# max         3.000000      10.000000       10.000000       10.000000
#
#        programmingLanguages  webDevelopment  databaseManagement  \
# count         487230.000000   487230.000000       487230.000000
# mean               3.012526        5.469829            5.496554
# std                1.422120        2.884502            2.874468
# min                1.000000        1.000000            1.000000
# 25%                2.000000        3.000000            3.000000
# 50%                3.000000        5.000000            6.000000
# 75%                4.000000        8.000000            8.000000
# max                5.000000       10.000000           10.000000
#
#        totalCoursesCompleted
# count          487230.000000
# mean               55.246886
# std                25.358268
# min                10.000000
# 25%                34.000000
# 50%                55.246886
# 75%                76.000000
# max               100.000000

# %%
df['employmentStatus'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Employment Status Breakdown')
plt.ylabel('')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the number of bins
bins = 20

# Create the figure with increased height
plt.figure(figsize=(6, 4))  # Increase the height by changing the second value

# Create the histogram and get the patches (bars)
counts, bin_edges, patches = plt.hist(df['totalCoursesCompleted'], bins=bins, edgecolor='black')

# Set the title and labels
plt.title('Distribution of Total Courses Completed')
plt.xlabel('Total Courses Completed')
plt.ylabel('Frequency')

# Create a color palette
colors = plt.cm.viridis(np.linspace(0, 1, len(patches)))

# Assign colors to each patch (bar)
for count, edge, patch in zip(counts, bin_edges, patches):
    patch.set_facecolor(colors[patches.index(patch)])  # Set the color for each bin
    # Annotate the count above each bar, adjust positions
    if count > 0:  # Only annotate if there is a count
        plt.text(edge + (bin_edges[1] - bin_edges[0]) / 2, count + 1, int(count), 
                 ha='center', va='bottom', fontsize=8, rotation=90)

# Adjust y-axis limits for better visibility
plt.ylim(0, max(counts) + 10)  # Increase space above the bars

# Show the plot
plt.tight_layout()
plt.show()

# %%
soft_skills = ['communication', 'teamwork', 'problemSolving', 'adaptability', 'timeManagement']
df[soft_skills].plot.box(figsize=(7, 4))
plt.title('Distribution of Soft Skills Ratings')
plt.ylabel('Skill Rating')

plt.show()

# %%
position_distribution = df['position'].value_counts()
print(position_distribution)
# Out:
# position
# Data Engineer        98532
# Software Engineer    98412
# Data Analyst         97629
# Consultant           96902
# Data Scientist       95755
# Name: count, dtype: int64

# %%
mean_communication = df['communication'].mean()
median_communication = df['communication'].median()
print(f"Mean Communication: {mean_communication}, Median Communication: {median_communication}")
# Out:
# Mean Communication: 5.492219280421978, Median Communication: 5.0

# %%
project_type_counts = df.groupby('projectType').size()
print(project_type_counts)
# Out:
# projectType
# Consulting              122441
# Data Science            121312
# Full Stack              120558
# Software Engineering    122919
# dtype: int64

# %%
# Set the figure size
plt.figure(figsize=(6, 4))

# Create a pivot table for completion status by specialization
completion_heatmap_data = df.pivot_table(index='specialization_x', columns='completionStatus', aggfunc='size', fill_value=0)

# Create a heatmap
sns.heatmap(completion_heatmap_data, annot=True, fmt='d', cmap='Blues')

# Set the title and labels
plt.title('Heatmap of Course Completion Status by Specialization')
plt.xlabel('Completion Status')
plt.ylabel('Specialization')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate course type counts
course_type_counts = df['courseType'].value_counts()

# Create a horizontal bar chart
plt.figure(figsize=(6, 4))
sns.barplot(y=course_type_counts.index, x=course_type_counts.values, palette='viridis')
plt.title('Course Types Offered')
plt.xlabel('Count')
plt.ylabel('Course Type')
plt.show()
# Out:
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\68817543.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=course_type_counts.index, x=course_type_counts.values, palette='viridis')

# %%
# Get the top 10 tools used by employees
tool_counts = df['toolsUsed'].value_counts().head(10)

# Set the figure size
plt.figure(figsize=(6, 6))

# Create a pie chart
plt.pie(tool_counts, labels=tool_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))

# Set the title
plt.title('Distribution of Top 10 Tools Used by Employees')

# Equal aspect ratio ensures that pie chart is a circle
plt.axis('equal')  

# Show the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(9, 4))

# Create a violin plot for communication scores by specialization
palette = sns.color_palette("Set2")  # Custom color palette

# Create the violin plot
violin_plot = sns.violinplot(data=df, x='specialization_x', y='communication', palette=palette)

# Set the title and labels
plt.title('Impact of Specialization on Communication Skills')
plt.ylabel('Communication Score')
plt.xlabel('Specialization')

# Rotate x-ticks for better readability


# Optionally, you can add the mean point for better understanding
mean_values = df.groupby('specialization_x')['communication'].mean()
for i, specialization in enumerate(mean_values.index):
    plt.text(i, mean_values[specialization] + 0.1, round(mean_values[specialization], 2), 
             horizontalalignment='center', size='medium', color='black', weight='semibold')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\2008911780.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   violin_plot = sns.violinplot(data=df, x='specialization_x', y='communication', palette=palette)
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\2008911780.py:8: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   violin_plot = sns.violinplot(data=df, x='specialization_x', y='communication', palette=palette)

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create a boxplot for communication ratings by platform
palette = sns.color_palette("Set2")  # Custom color palette

# Create the boxplot
boxplot = sns.boxplot(data=df, x='platform_x', y='communication', palette=palette)

# Set the title and labels
plt.title('Performance Ratings by Course Platform')
plt.ylabel('Communication Score')
plt.xlabel('Course Platform')

# Rotate x-ticks for better readability
plt.xticks(rotation=45)

# Optionally, you can add the mean point for better understanding
mean_values = df.groupby('platform_x')['communication'].mean()
for i, platform in enumerate(mean_values.index):
    plt.text(i, mean_values[platform] + 0.1, round(mean_values[platform], 2), 
             horizontalalignment='center', size='medium', color='black', weight='semibold')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\4004917452.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   boxplot = sns.boxplot(data=df, x='platform_x', y='communication', palette=palette)
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\4004917452.py:8: UserWarning: The palette list has more values (8) than needed (5), which may not be intended.
#   boxplot = sns.boxplot(data=df, x='platform_x', y='communication', palette=palette)

# %%
# Set the color palette for the count plot
palette = sns.color_palette("viridis", len(df['competencyLevel'].value_counts()))

# Create a count plot for competency levels
plt.figure(figsize=(7, 5))
count_plot = sns.countplot(data=df, x='competencyLevel', palette=palette)

# Adding count labels on top of each bar
for p in count_plot.patches:
    count_plot.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='bottom')

# Set titles and labels
plt.title('Competency Level Distribution')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Optionally, set y-axis limit (you can adjust the limit if needed)
# plt.ylim(0, max(df['competencyLevel'].value_counts()) + 10)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SanthoshKumarE\AppData\Local\Temp\ipykernel_17672\1545335936.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   count_plot = sns.countplot(data=df, x='competencyLevel', palette=palette)

# %%
# Calculate the average communication score by specialization
improvement_by_specialization = df.groupby('specialization_x')['communication'].mean()

# Create a bar plot with different colors for each bar
colors = plt.cm.viridis(np.linspace(0, 1, len(improvement_by_specialization)))  # Different color for each bar

# Plotting the bar chart
plt.figure(figsize=(7, 5))
bars = plt.bar(improvement_by_specialization.index, improvement_by_specialization.values, color=colors)

# Adding average score labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set y-axis limit
plt.ylim(0, 10)

# Set titles and labels
plt.title('Average Communication Improvement by Specialization')
plt.ylabel('Average Communication Score')
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Feature Engineering & Feature Selection

# %%
#Total Projects:

df['total_projects'] = df[['softwareEngineerProjects', 'consultantProjects', 'fullStackProjects', 
                             'dataAnalystProjects', 'dataEngineerProjects', 'dataScienceProjects', 
                             'otherProjects']].sum(axis=1)

# %%
#Communication Score:

df['soft_skills_score'] = df[['communication', 'problemSolving']].mean(axis=1)

# %%
#Project Type Count:

df['unique_project_types'] = df['projectType'].apply(lambda x: len(set(x.split(','))) if pd.notnull(x) else 0)

# %%
#Education Level:

df['courseType_encoded'] = df['courseType'].map({'Certification': 1, 'Degree': 2, 'Diploma': 3}).fillna(0)

# %% [markdown]
# Feature Transformation

# %%
#Encoding Categorical Variables:

df = pd.get_dummies(df, columns=['position','employmentStatus'], drop_first=True)

# %%
#Scaling Numerical Features:
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['softwareEngineerProjects', 'consultantProjects', 'fullStackProjects', 'dataAnalystProjects', 
    'dataEngineerProjects', 'dataScienceProjects', 'otherProjects', 'communication', 'soft_skills_score']] = scaler.fit_transform(
    df[['softwareEngineerProjects', 'consultantProjects', 'fullStackProjects', 'dataAnalystProjects', 
        'dataEngineerProjects', 'dataScienceProjects', 'otherProjects', 'communication', 'soft_skills_score']])

# %%
#Binning Numerical Variables

df['communication_binned'] = pd.cut(df['communication'], bins=[0, 3, 6, 10], labels=['Low', 'Medium', 'High'])

# %%
# Concatenating firstName and lastName to create employeeName
df['employeeName'] = df['firstName'] + ' ' + df['lastName']

# Display the updated DataFrame to verify the new column
print(df[['firstName', 'lastName', 'employeeName']].head())

columns = ['employeeName'] + [col for col in df.columns if col != 'employeeName']
df = df[columns]
# Out:
#         firstName lastName            employeeName
# 0  Edgar Williams  Hawkins  Edgar Williams Hawkins
# 1  Edgar Williams  Hawkins  Edgar Williams Hawkins
# 2  Edgar Williams  Hawkins  Edgar Williams Hawkins
# 3  Edgar Williams  Hawkins  Edgar Williams Hawkins
# 4  Caitlin Wilson   Nguyen   Caitlin Wilson Nguyen

# %%
df.head()
# Out:
#              employeeName       firstName lastName employeeid  \
# 0  Edgar Williams Hawkins  Edgar Williams  Hawkins    JMD9745
# 1  Edgar Williams Hawkins  Edgar Williams  Hawkins    JMD9745
# 2  Edgar Williams Hawkins  Edgar Williams  Hawkins    JMD9745
# 3  Edgar Williams Hawkins  Edgar Williams  Hawkins    JMD9745
# 4   Caitlin Wilson Nguyen  Caitlin Wilson   Nguyen    JMD2737
#
#                                  userId  softwareEngineerProjects  \
# 0  0000aaaf-2a69-41fb-824b-975974e3a198                 -1.588389
# 1  0000aaaf-2a69-41fb-824b-975974e3a198                 -1.588389
# 2  0000aaaf-2a69-41fb-824b-975974e3a198                 -1.588389
# 3  0000aaaf-2a69-41fb-824b-975974e3a198                 -1.588389
# 4  0001d2a9-1b26-4bc5-b1de-a55e58696e32                 -0.008094
#
#    consultantProjects  fullStackProjects  dataAnalystProjects  \
# 0            1.463213          -0.291050             1.454574
# 1            1.463213          -0.291050             1.454574
# 2            1.463213          -0.291050             1.454574
# 3            1.463213          -0.291050             1.454574
# 4           -0.877136           0.294569            -0.296013
#
#    dataEngineerProjects  dataScienceProjects  otherProjects  \
# 0              0.003828            -1.576241       1.345841
# 1              0.003828            -1.576241       1.345841
# 2              0.003828            -1.576241       1.345841
# 3              0.003828            -1.576241       1.345841
# 4             -0.311460            -1.261006      -1.338872
#
#             projectType toolsUsed     favoriteProject  communication  \
# 0          Data Science   Tableau     Them fact care.       0.176568
# 1          Data Science   Tableau     Them fact care.       0.176568
# 2          Data Science   Tableau     Them fact care.       0.176568
# 3          Data Science   Tableau     Them fact care.       0.176568
# 4  Software Engineering   Node.js  Seem nature story.       1.219742
#
#        teamwork  problemSolving adaptability  timeManagement criticalThinking  \
# 0     Innovator              10    Visionary               4           Leader
# 1     Innovator              10    Visionary               4           Leader
# 2     Innovator              10    Visionary               4           Leader
# 3     Innovator              10    Visionary               4           Leader
# 4  Collaborator              10    Visionary               3       Strategist
#
#    creativity leadership interpersonalSkills emotionalIntelligence  \
# 0  Innovative    Manager            Empathic                Leader
# 1  Innovative    Manager            Empathic                Leader
# 2  Innovative    Manager            Empathic                Leader
# 3  Innovative    Manager            Empathic                Leader
# 4   Visionary  Innovator            Empathic              Empathic
#
#    programmingLanguages  webDevelopment  databaseManagement   cloudComputing  \
# 0                     5               4                   4           Master
# 1                     5               4                   4           Master
# 2                     5               4                   4           Master
# 3                     5               4                   4           Master
# 4                     3               2                   3  Very proficient
#
#           versionControl machineLearning  dataAnalysis          cybersecurity  \
# 0                 Master        Beginner      Beginner                 Master
# 1                 Master        Beginner      Beginner                 Master
# 2                 Master        Beginner      Beginner                 Master
# 3                 Master        Beginner      Beginner                 Master
# 4  Moderately proficient        Beginner  Intermediate  Moderately proficient
#
#          courseName         platform_x      specialization_x  \
# 0   Web Development              Udemy  Software Engineering
# 1            Python                ADF          Data Science
# 2  Machine Learning  LinkedIn Learning          Data Science
# 3  Machine Learning                edX          Data Science
# 4   Web Development  LinkedIn Learning       Web Development
#
#    totalCoursesCompleted        courseType completionStatus  \
# 0                   47.0     Online Course      In Progress
# 1                   52.0  In-Person Course        Completed
# 2                   83.0     Online Course        Completed
# 3                   93.0     Online Course        Completed
# 4                   24.0  In-Person Course      In Progress
#
#   certificationTitle platform_y specialization_y competencyLevel  \
# 0       Data Science   Coursera  Cloud Computing        Beginner
# 1       Data Science   Coursera  Cloud Computing        Beginner
# 2       Data Science   Coursera  Cloud Computing        Beginner
# 3       Data Science   Coursera  Cloud Computing        Beginner
# 4                AWS        edX  Web Development        Beginner
#
#    total_projects  soft_skills_score  unique_project_types  \
# 0              20           1.230164                     1
# 1              20           1.230164                     1
# 2              20           1.230164                     1
# 3              20           1.230164                     1
# 4              16           1.968931                     1
#
#    courseType_encoded  position_Data Analyst  position_Data Engineer  \
# 0                 0.0                  False                    True
# 1                 0.0                  False                    True
# 2                 0.0                  False                    True
# 3                 0.0                  False                    True
# 4                 0.0                  False                   False
#
#    position_Data Scientist  position_Software Engineer  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                       False
# 4                     True                       False
#
#    employmentStatus_full_time  employmentStatus_part_time communication_binned
# 0                       False                       False                  Low
# 1                       False                       False                  Low
# 2                       False                       False                  Low
# 3                       False                       False                  Low
# 4                       False                       False                  Low

# %%
df.columns
# Out:
# Index(['employeeName', 'firstName', 'lastName', 'employeeid', 'userId',
#        'softwareEngineerProjects', 'consultantProjects', 'fullStackProjects',
#        'dataAnalystProjects', 'dataEngineerProjects', 'dataScienceProjects',
#        'otherProjects', 'projectType', 'toolsUsed', 'favoriteProject',
#        'communication', 'teamwork', 'problemSolving', 'adaptability',
#        'timeManagement', 'criticalThinking', 'creativity', 'leadership',
#        'interpersonalSkills', 'emotionalIntelligence', 'programmingLanguages',
#        'webDevelopment', 'databaseManagement', 'cloudComputing',
#        'versionControl', 'machineLearning', 'dataAnalysis', 'cybersecurity',
#        'courseName', 'platform_x', 'specialization_x', 'totalCoursesCompleted',
#        'courseType', 'completionStatus', 'certificationTitle', 'platform_y',
#        'specialization_y', 'competencyLevel', 'total_projects',
#        'soft_skills_score', 'unique_project_types', 'courseType_encoded',
#        'position_Data Analyst', 'position_Data Engineer',
#        'position_Data Scientist', 'position_Software Engineer',
#        'employmentStatus_full_time', 'employmentStatus_part_time',
#        'communication_binned'],
#       dtype='object')

# %% [markdown]
# Feature selection

# %%
# Dropping specified columns
columns_to_drop = ['firstName', 'lastName', 'userId', 'totalCoursesCompleted', 'employeeName','platform_x','specialization_y']
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#   employeeid  softwareEngineerProjects  consultantProjects  fullStackProjects  \
# 0    JMD9745                 -1.588389            1.463213          -0.291050
# 1    JMD9745                 -1.588389            1.463213          -0.291050
# 2    JMD9745                 -1.588389            1.463213          -0.291050
# 3    JMD9745                 -1.588389            1.463213          -0.291050
# 4    JMD2737                 -0.008094           -0.877136           0.294569
#
#    dataAnalystProjects  dataEngineerProjects  dataScienceProjects  \
# 0             1.454574              0.003828            -1.576241
# 1             1.454574              0.003828            -1.576241
# 2             1.454574              0.003828            -1.576241
# 3             1.454574              0.003828            -1.576241
# 4            -0.296013             -0.311460            -1.261006
#
#    otherProjects           projectType toolsUsed     favoriteProject  \
# 0       1.345841          Data Science   Tableau     Them fact care.
# 1       1.345841          Data Science   Tableau     Them fact care.
# 2       1.345841          Data Science   Tableau     Them fact care.
# 3       1.345841          Data Science   Tableau     Them fact care.
# 4      -1.338872  Software Engineering   Node.js  Seem nature story.
#
#    communication      teamwork  problemSolving adaptability  timeManagement  \
# 0       0.176568     Innovator              10    Visionary               4
# 1       0.176568     Innovator              10    Visionary               4
# 2       0.176568     Innovator              10    Visionary               4
# 3       0.176568     Innovator              10    Visionary               4
# 4       1.219742  Collaborator              10    Visionary               3
#
#   criticalThinking  creativity leadership interpersonalSkills  \
# 0           Leader  Innovative    Manager            Empathic
# 1           Leader  Innovative    Manager            Empathic
# 2           Leader  Innovative    Manager            Empathic
# 3           Leader  Innovative    Manager            Empathic
# 4       Strategist   Visionary  Innovator            Empathic
#
#   emotionalIntelligence  programmingLanguages  webDevelopment  \
# 0                Leader                     5               4
# 1                Leader                     5               4
# 2                Leader                     5               4
# 3                Leader                     5               4
# 4              Empathic                     3               2
#
#    databaseManagement   cloudComputing         versionControl machineLearning  \
# 0                   4           Master                 Master        Beginner
# 1                   4           Master                 Master        Beginner
# 2                   4           Master                 Master        Beginner
# 3                   4           Master                 Master        Beginner
# 4                   3  Very proficient  Moderately proficient        Beginner
#
#    dataAnalysis          cybersecurity        courseName  \
# 0      Beginner                 Master   Web Development
# 1      Beginner                 Master            Python
# 2      Beginner                 Master  Machine Learning
# 3      Beginner                 Master  Machine Learning
# 4  Intermediate  Moderately proficient   Web Development
#
#        specialization_x        courseType completionStatus certificationTitle  \
# 0  Software Engineering     Online Course      In Progress       Data Science
# 1          Data Science  In-Person Course        Completed       Data Science
# 2          Data Science     Online Course        Completed       Data Science
# 3          Data Science     Online Course        Completed       Data Science
# 4       Web Development  In-Person Course      In Progress                AWS
#
#   platform_y competencyLevel  total_projects  soft_skills_score  \
# 0   Coursera        Beginner              20           1.230164
# 1   Coursera        Beginner              20           1.230164
# 2   Coursera        Beginner              20           1.230164
# 3   Coursera        Beginner              20           1.230164
# 4        edX        Beginner              16           1.968931
#
#    unique_project_types  courseType_encoded  position_Data Analyst  \
# 0                     1                 0.0                  False
# 1                     1                 0.0                  False
# 2                     1                 0.0                  False
# 3                     1                 0.0                  False
# 4                     1                 0.0                  False
#
#    position_Data Engineer  position_Data Scientist  \
# 0                    True                    False
# 1                    True                    False
# 2                    True                    False
# 3                    True                    False
# 4                   False                     True
#
#    position_Software Engineer  employmentStatus_full_time  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    employmentStatus_part_time communication_binned
# 0                       False                  Low
# 1                       False                  Low
# 2                       False                  Low
# 3                       False                  Low
# 4                       False                  Low

# %%
df.dtypes
# Out:
# employeeid                      object
# softwareEngineerProjects       float64
# consultantProjects             float64
# fullStackProjects              float64
# dataAnalystProjects            float64
# dataEngineerProjects           float64
# dataScienceProjects            float64
# otherProjects                  float64
# projectType                     object
# toolsUsed                       object
# favoriteProject                 object
# communication                  float64
# teamwork                        object
# problemSolving                   int64
# adaptability                    object
# timeManagement                   int64
# criticalThinking                object
# creativity                      object
# leadership                      object
# interpersonalSkills             object
# emotionalIntelligence           object
# programmingLanguages             int64
# webDevelopment                   int64
# databaseManagement               int64
# cloudComputing                  object
# versionControl                  object
# machineLearning                 object
# dataAnalysis                    object
# cybersecurity                   object
# courseName                      object
# specialization_x                object
# courseType                      object
# completionStatus                object
# certificationTitle              object
# platform_y                      object
# competencyLevel                 object
# total_projects                   int64
# soft_skills_score              float64
# unique_project_types             int64
# courseType_encoded             float64
# position_Data Analyst             bool
# position_Data Engineer            bool
# position_Data Scientist           bool
# position_Software Engineer        bool
# employmentStatus_full_time        bool
# employmentStatus_part_time        bool
# communication_binned          category
# dtype: object

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from scipy.sparse import csr_matrix
from scipy.sparse import csr_matrix, hstack
from sklearn.decomposition import TruncatedSVD

# Assuming 'df' is your DataFrame with the provided data
# Combine relevant text features into a single string for each employee
df['combined_features'] = (
    df['employeeid'].astype(str) + " " + 
    df['specialization_x'].fillna('') + " " +
    df['competencyLevel'].fillna('') + " " +
    df['toolsUsed'].fillna('') + " " +
    df['favoriteProject'].fillna('') + " " +
    df['projectType'].fillna('') + " " +
    df['teamwork'].fillna('') + " " +
    df['adaptability'].fillna('') + " " +
    df['criticalThinking'].fillna('') + " " +
    df['creativity'].fillna('') + " " +
    df['leadership'].fillna('') + " " +
    df['interpersonalSkills'].fillna('') + " " +
    df['emotionalIntelligence'].fillna('') + " " +
    df['cloudComputing'].fillna('') + " " +
    df['versionControl'].fillna('') + " " +
    df['machineLearning'].fillna('') + " " +
    df['dataAnalysis'].fillna('') + " " +
    df['cybersecurity'].fillna('')
)

# Use TF-IDF Vectorizer to convert text data into feature vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# Select numeric and boolean features to be included
numeric_features = [
    'softwareEngineerProjects', 'consultantProjects', 'fullStackProjects',
    'dataAnalystProjects', 'dataEngineerProjects', 'dataScienceProjects',
    'otherProjects', 'communication', 'problemSolving', 'timeManagement',
    'programmingLanguages', 'webDevelopment', 'databaseManagement',
    'total_projects', 'soft_skills_score', 'unique_project_types', 'courseType_encoded'
]

# Boolean features
boolean_features = [
    'position_Data Analyst', 'position_Data Engineer', 'position_Data Scientist', 
    'position_Software Engineer', 'employmentStatus_full_time', 'employmentStatus_part_time'
]

# %%
# # Standardize the numeric features
# scaler = StandardScaler()
# scaled_numeric_features = scaler.fit_transform(df[numeric_features].fillna(0))

# # Create a sparse matrix from scaled numeric and boolean features
# scaled_numeric_features_sparse = csr_matrix(scaled_numeric_features)

# # Combine TF-IDF features with scaled numeric and boolean features
# # Note: We'll create a sparse matrix for the combined features
# from scipy.sparse import hstack

# combined_features_matrix = hstack([
#     tfidf_matrix, 
#     scaled_numeric_features_sparse, 
#     csr_matrix(df[boolean_features].values)  # Convert boolean features to sparse
# ])

# # Calculate cosine similarity using sparse matrix
# cosine_sim = cosine_similarity(combined_features_matrix)

# %%
# Standardize the numeric features
scaler = StandardScaler()
scaled_numeric_features = scaler.fit_transform(df[numeric_features].fillna(0))

# %%
# Create a sparse matrix from scaled numeric and boolean features
scaled_numeric_features_sparse = csr_matrix(scaled_numeric_features)

# %%
# Step 5: Combine TF-IDF features with scaled numeric and boolean features
combined_features_matrix = hstack([
    tfidf_matrix, 
    scaled_numeric_features_sparse, 
    csr_matrix(df[boolean_features].values)
])

# %%
# Perform dimensionality reduction on the TF-IDF matrix
svd = TruncatedSVD(n_components=20)  # Adjust as needed
tfidf_reduced = svd.fit_transform(tfidf_matrix)

# %%
combined_features_matrix = hstack([
    csr_matrix(tfidf_reduced),  # Ensure this is a sparse matrix
    scaled_numeric_features_sparse, 
    csr_matrix(df[boolean_features].values)
])

# %%
import numpy as np
from scipy.sparse import csr_matrix

# Assuming combined_features_matrix is your original sparse matrix
num_rows = combined_features_matrix.shape[0]  # Total number of rows
num_sample_rows = 20000  # Number of rows to sample

# Randomly choose indices for 50,000 rows
random_indices = np.random.choice(num_rows, size=num_sample_rows, replace=False)

# Select only the chosen rows
sampled_sparse_matrix = combined_features_matrix[random_indices, :]

# Check the shape of the new sparse matrix
print(sampled_sparse_matrix.shape)
# Out:
# (20000, 43)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(sampled_sparse_matrix)

# Display the shape of the cosine similarity matrix
print("Cosine Similarity Matrix Shape:", cosine_sim.shape)
# Out:
# Cosine Similarity Matrix Shape: (20000, 20000)

# %%
# Function to recommend courses for a given employee index

def recommend_courses(employeeid, df, cosine_sim, top_n=5):

    """

    Recommend courses for a given employee index based on cosine similarity.

    

    Parameters:

    employee_id (int): Index of the employee in the DataFrame.

    df (DataFrame): The original DataFrame containing course information.

    cosine_sim (ndarray): Cosine similarity matrix.

    top_n (int): Number of recommendations to return.



    Returns:

    DataFrame: DataFrame containing recommended courses and platforms.

    """

    # # Get similarity scores for the given employee

    # sim_scores = list(enumerate(cosine_sim[employee_id]))

    

    # # Sort courses based on similarity scores (descending)

    # sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    

    # # Get indices of the top_n similar profiles (excluding the employee themselves)

    # sim_scores = sim_scores[1:top_n+1]

    

    # # Retrieve course indices from similarity scores

    # course_indices = [i[0] for i in sim_scores]

    

    # # Create a DataFrame for the recommended courses

    # recommended_courses = df.iloc[course_indices][['courseName', 'platform_y', 'competencyLevel']]

    

    # return recommended_courses



 # Find all indices corresponding to the given employee_id
    employee_indices = df[df['employeeid'] == employeeid].index.tolist()
    
    # Ensure there are rows with the given employee_id
    if not employee_indices:
        print(f"No data found for employee ID: {employeeid}")
        return pd.DataFrame()

    # Select the first index as the reference employee for recommendations
    employee_index = employee_indices[0]

    # Get similarity scores for the given employee
    sim_scores = list(enumerate(cosine_sim[employee_index]))
    
    # Sort courses based on similarity scores (descending)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get indices of the top_n similar profiles (excluding the employee themselves)
    sim_scores = sim_scores[1:top_n + 1]
    
    # Retrieve course indices from similarity scores
    course_indices = [i[0] for i in sim_scores]
    
    # Create a DataFrame for the recommended courses
    recommended_courses = df.iloc[course_indices][['courseName', 'platform_y', 'competencyLevel']]
    
    # Add a message indicating which employee ID the recommendations are for
    print(f"Recommendations for Employee ID: {employeeid}")
    
    # Return the recommended courses as a DataFrame for display
    return recommended_courses.reset_index(drop=True)

# %%
employeeid = 'JMD6028'
  # Replace this with the actual ID of the employee you want to get recommendations for
recommended_courses = recommend_courses(employeeid, df, cosine_sim, top_n=5)

# Print the recommended courses
print(recommended_courses)
# Out:
# Recommendations for Employee ID: JMD6028
#          courseName         platform_y competencyLevel
# 0   Web Development           Coursera        Beginner
# 1  Machine Learning             Google        Beginner
# 2  Machine Learning  LinkedIn Learning        Advanced
# 3  Machine Learning  LinkedIn Learning    Intermediate
# 4  Machine Learning           Coursera        Advanced
